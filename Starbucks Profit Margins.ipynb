# %% [markdown]
# <p align="center">
#     <img src="https://s22.q4cdn.com/869488222/files/design/starbucks-logo.svg" />
# </p>

# %% [markdown]
# # ☕💸📈 **Varying selling prices means that profit margins of each drink will need to be compared based on a common attribute, thus, profits will be determined based on a percentage calculated from the ratio of the difference between sell price and production cost to the total sell price ( sell price - production cost / sell price ). Finding the average profit amongst all drinks and calculating the lower boundary for outliers will be the basis of determining whether or not a drink should be removed from the menu. Potentially, an additional feature can be added recording the popularity of certain drinks that may affect whether it should be removed from the menu or not as to maintain customer relations.**

# %% [markdown]
# # ***Dimensioning***

# %% [markdown]
# ***Overview***

# %% [markdown]
# # **🔴1.Import Libraries**

# %%
import numpy as np
import pandas as pd

# %%
# Customize the display window
# pd.set_option("display.max_columns", None)
# pd.set_option("display.width",500)

# %% [markdown]
# # 🟠**2.Introducing the dataset**

# %%
#pip install kaggle 
# go to https://www.kaggle.com, log in, click the profile icon > account > create API token
# place the kaggle.json file in your .kaggle folder
# the file will be downloaded into the same folder as this jupyter notebook

# from kaggle.api.kaggle_api_extended import KaggleApi
# api = KaggleApi()
# api.authenticate()
# api.dataset_download_file('syedasimalishah/starbucks-drinks','starbucks_drinks.csv')

# df = pd.read_csv('<directory>')
# df.head()

data = pd.read_csv('starbucks_drinks.csv').T.to_dict()
# for i in range(5):
#     print(data[i])

df = pd.DataFrame.from_dict(data, orient='index')

df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %% [markdown]
# # 🟡**3. Prepping the data & adding custom data**

# %% [markdown]
# ***Adding the cost per ingrediant data***
# - Calculate the cost of ingredients and profit margins for each drink on the Starbucks menu.

# %% [markdown]
# ***converting or grouping data. One-hot rule or other rules***

# %% [markdown]
# # 🟢**4. Identify the most profitable and least profitable drinks on the menu.**

# %% [markdown]
# # 🔵**5. Analyze the relationships between price, ingredients, and profit margins.**

# %% [markdown]
# # 🟣**6. Determine if there are any drinks that are consistently unprofitable and should be removed from the menu.**

# %% [markdown]
# # 🟤**7. Provide recommendations for menu optimization that could increase profits while keeping the drink's sellability.**

# %% [markdown]
# # ⚫**8. Evaluate the recommendations and suggest an optimal drink that would maximize profits and customer satisfaction.**

# %% [markdown]
# # ⚪**9. Plotting and Explaining**
